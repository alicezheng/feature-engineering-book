# %%
import pandas as pd
import json
biz_f = open('data/yelp/v6/yelp_dataset_challenge_academic_dataset/yelp_academic_dataset_business.json')
biz_df = pd.DataFrame([json.loads(x) for x in biz_f.readlines()])
biz_f.close()

# %%
import numpy as np
biz_df['log_review_count'] = np.log10(biz_df['review_count'] + 1)

# %%
from sklearn import linear_model
from sklearn.model_selection import cross_val_score

# %%
m_orig = linear_model.LinearRegression()
scores_orig = cross_val_score(m_orig, biz_df[['review_count']], biz_df['stars'], cv=10)

# %%
print("R-squared score: %0.5f (+/- %0.5f)" % (scores_orig.mean(), scores_orig.std() * 2))
# Out:
# R-squared score: -0.03683 (+/- 0.07280)

# %%
m_log = linear_model.LinearRegression()
scores_log = cross_val_score(m_log, biz_df[['log_review_count']], biz_df['stars'], cv=10)

# %%
print("R-squared score: %0.5f (+/- %0.5f)" % (scores_log.mean(), scores_log.std() * 2))
# Out:
# R-squared score: -0.03694 (+/- 0.07650)

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
ax1 = plt.subplot(2,1,1)
ax1.scatter(biz_df['review_count'], biz_df['stars'])
ax2 = plt.subplot(2,1,2)
ax2.scatter(biz_df['log_review_count'], biz_df['stars'])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
skillcraft_df = pd.read_csv('data/SkillCraft1_Dataset.csv')
skillcraft_df
# Out:
#       GameID  LeagueIndex Age HoursPerWeek TotalHours       APM  \
# 0         52            5  27           10       3000  143.7180
# 1         55            5  23           10       5000  129.2322
# 2         56            4  30           10        200   69.9612
# 3         57            3  19           20        400  107.6016
# 4         58            3  32           10        500  122.8908
# 5         60            2  27            6         70   44.4570
# 6         61            1  21            8        240   46.9962
# 7         72            7  17           42      10000  212.6022
# 8         77            4  20           14       2708  117.4884
# 9         81            4  18           24        800  155.9856
# 10        83            3  16           16       6000  153.8010
# 11        93            4  26            4        190   79.2948
# 12        97            3  18           12        350   67.4754
# 13        98            3  38            6       1000  119.4366
# ...
